# %% [markdown]
# # Exploratory Data Analysis (EDA) on a Movies Dataset

# %%
#1. importing the libraries and completing setup

# i)pandas for working with the dataframes
import pandas as pd
# ii)matplotlib for the plotting of the data 
import matplotlib.pyplot as plt
# ii) numpy for dealing with any calculations
import numpy as np
# iii)reading the csv file and converting it into a data frame
movies = pd.read_csv("IMDb_Dataset.csv",index_col = 0)

# %%
# 2. Initial Exploratory Data Analysis (EDA)
#   i)the basic view of our dataframe and top 5 data entries
movies.head()
# Out:
#                                                IMDb Rating  Year Certificates  \
# Title
# Gladiator                                              8.5  2000            R
# Mission: Impossible - Dead Reckoning Part One          7.7  2023        PG-13
# Rebel Moon - Part Two: The Scargiver                   5.2  2024        PG-13
# Inglourious Basterds                                   8.4  2009            R
# Borderlands                                            7.1  2024            R
#
#                                                    Genre  \
# Title
# Gladiator                                         Action
# Mission: Impossible - Dead Reckoning Part One     Action
# Rebel Moon - Part Two: The Scargiver              Action
# Inglourious Basterds                           Adventure
# Borderlands                                       Action
#
#                                                             Director  \
# Title
# Gladiator                                               Ridley Scott
# Mission: Impossible - Dead Reckoning Part One  Christopher McQuarrie
# Rebel Moon - Part Two: The Scargiver                     Zack Snyder
# Inglourious Basterds                               Quentin Tarantino
# Borderlands                                                 Eli Roth
#
#                                                                                Star Cast  \
# Title
# Gladiator                                      David FranzoniJohn LoganWilliam Nicholson
# Mission: Impossible - Dead Reckoning Part One         Tom CruiseHayley AtwellVing Rhames
# Rebel Moon - Part Two: The Scargiver                 Zack SnyderKurt JohnstadShay Hatten
# Inglourious Basterds                                       Brad PittDiane KrugerEli Roth
# Borderlands                                                          Eli RothJoe Crombie
#
#                                                MetaScore  Duration (minutes)
# Title
# Gladiator                                           67.0               155.0
# Mission: Impossible - Dead Reckoning Part One       81.0               163.0
# Rebel Moon - Part Two: The Scargiver                35.0               122.0
# Inglourious Basterds                                69.0               153.0
# Borderlands                                         66.9               116.3

# %%
#   ii) all the columns and their datatypes and entry's information
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, Gladiator to The Fall Guy
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   IMDb Rating         400 non-null    float64
#  1   Year                400 non-null    int64
#  2   Certificates        400 non-null    object
#  3   Genre               400 non-null    object
#  4   Director            400 non-null    object
#  5   Star Cast           400 non-null    object
#  6   MetaScore           400 non-null    float64
#  7   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 28.1+ KB

# %%
#   iii) the number of non-null values, The arithmetic mean of the values, The standard deviation, a measure of data dispersion, The minimum value, first quartile, median, third quartile, The maximum value.
movies.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
#   iv) the rows and column information
print("Number of rows in the dataframe:",movies.shape[0])
print("Number of Columns in the dataframe:",movies.shape[1])
# Out:
# Number of rows in the dataframe: 400
# Number of Columns in the dataframe: 8

# %%
# v)chexking for any missing value and filling it with 0 just incase
if(movies.isna().sum().sum()!=0):
    movies.fillna(0)
movies.isna().sum()
# Out:
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
#   vi) top rated movies
top_rated = movies.sort_values("IMDb Rating", ascending=False)
top_rated = top_rated.drop_duplicates(subset="IMDb Rating")
top_rated.head(10)
# Out:
#                         IMDb Rating  Year Certificates      Genre  \
# Title
# The Godfather                   9.2  1972            R      Crime
# 12 Angry Men                    9.0  1957     Approved      Crime
# Pulp Fiction                    8.9  1994            R      Crime
# Inception                       8.8  2010        PG-13     Action
# The Matrix                      8.7  1999            R     Action
# Spirited Away                   8.6  2001           PG  Animation
# The Departed                    8.5  2006            R      Crime
# Manjummel Boys                  8.4  2024            R  Adventure
# Heat                            8.3  1995            R     Action
# No Country for Old Men          8.2  2007            R      Crime
#
#                                     Director  \
# Title
# The Godfather           Francis Ford Coppola
# 12 Angry Men                    Sidney Lumet
# Pulp Fiction               Quentin Tarantino
# Inception                  Christopher Nolan
# The Matrix                    Lana Wachowski
# Spirited Away                 Hayao Miyazaki
# The Departed                 Martin Scorsese
# Manjummel Boys                   Chidambaram
# Heat                            Michael Mann
# No Country for Old Men            Ethan Coen
#
#                                                                Star Cast  \
# Title
# The Godfather                             Mario PuzoFrancis Ford Coppola
# 12 Angry Men                                               Reginald Rose
# Pulp Fiction                                Quentin TarantinoRoger Avary
# Inception               Leonardo DiCaprioJoseph Gordon-LevittElliot Page
# The Matrix                Keanu ReevesLaurence FishburneCarrie-Anne Moss
# Spirited Away                                             Hayao Miyazaki
# The Departed                   Leonardo DiCaprioMatt DamonJack Nicholson
# Manjummel Boys                  Soubin ShahirSreenath BhasiBalu Varghese
# Heat                                   Al PacinoRobert De NiroVal Kilmer
# No Country for Old Men           Tommy Lee JonesJavier BardemJosh Brolin
#
#                         MetaScore  Duration (minutes)
# Title
# The Godfather               100.0               175.0
# 12 Angry Men                 97.0                96.0
# Pulp Fiction                 95.0               154.0
# Inception                    74.0               148.0
# The Matrix                   73.0               136.0
# Spirited Away                96.0               125.0
# The Departed                 85.0               151.0
# Manjummel Boys               66.9               116.3
# Heat                         76.0               170.0
# No Country for Old Men       92.0               122.0

# %%
# visualizing top rated movies
top_10_B = top_rated.head(10)
plt.figure(figsize=(10,5))
plt.barh(top_10_B.index,top_10_B["IMDb Rating"],color="skyblue")
plt.xticks(np.arange(0, 10.5, 0.5))
plt.xlabel("IMDb Rating")
plt.ylabel("Movie Title")
plt.title("Top 10 Movies")
plt.show()

# %%
#   vii) worst rated movies
worst_rated = movies.sort_values("IMDb Rating")
worst_rated=worst_rated.drop_duplicates(subset="IMDb Rating")
worst_rated.head(10)
# Out:
#                                       IMDb Rating  Year Certificates   Genre  \
# Title
# Madame Web                                    3.9  2024        PG-13  Action
# You Can't Run Forever                         4.4  2024            R   Drama
# Monster                                       4.6  2023        TV-MA  Horror
# Mother of the Bride                           4.8  2024        TV-PG  Comedy
# Tarot                                         4.9  2024        PG-13  Horror
# The Strangers: Chapter 1                      5.0  2024            R  Horror
# Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13  Action
# The Invitation                                5.3  2022        PG-13  Horror
# Five Nights at Freddy's                       5.5  2023        PG-13  Horror
# Atlas                                         5.6  2024        PG-13  Action
#
#                                                  Director  \
# Title
# Madame Web                                  S.J. Clarkson
# You Can't Run Forever                 Michelle Schumacher
# Monster                                     Rako Prijanto
# Mother of the Bride                           Mark Waters
# Tarot                                       Spenser Cohen
# The Strangers: Chapter 1                     Renny Harlin
# Rebel Moon - Part Two: The Scargiver          Zack Snyder
# The Invitation                        Jessica M. Thompson
# Five Nights at Freddy's                        Emma Tammi
# Atlas                                         Brad Peyton
#
#                                                                          Star Cast  \
# Title
# Madame Web                                  Matt SazamaBurk SharplessClaire Parker
# You Can't Run Forever                     J.K. SimmonsFernanda UrrejolaAllen Leech
# Monster                                     Marsha TimothyAlex AbbadAnantya Kirana
# Mother of the Bride                   Brooke ShieldsMiranda CosgroveBenjamin Bratt
# Tarot                                     Harriet SlaterAdain BradleyJacob Batalon
# The Strangers: Chapter 1                     Madelaine PetschRyan BownMatus Lajcak
# Rebel Moon - Part Two: The Scargiver           Zack SnyderKurt JohnstadShay Hatten
# The Invitation                         Nathalie EmmanuelThomas DohertySean Pertwee
# Five Nights at Freddy's                      Scott CawthonSeth CuddebackEmma Tammi
# Atlas                                      Jennifer LopezSimu LiuSterling K. Brown
#
#                                       MetaScore  Duration (minutes)
# Title
# Madame Web                                 26.0               116.0
# You Can't Run Forever                      66.9               102.0
# Monster                                    66.9                86.0
# Mother of the Bride                        39.0                88.0
# Tarot                                      36.0                92.0
# The Strangers: Chapter 1                   43.0                91.0
# Rebel Moon - Part Two: The Scargiver       35.0               122.0
# The Invitation                             45.0               105.0
# Five Nights at Freddy's                    33.0               109.0
# Atlas                                      37.0               118.0

# %%
# visualizing worst rated movies
top_10_W = worst_rated.head(10)
plt.figure(figsize=(10,5))
plt.barh(top_10_W.index,top_10_W["IMDb Rating"],color="skyblue")
plt.xticks(np.arange(0, 7, 0.5))
plt.xlabel("IMDb Rating")
plt.ylabel("Movie Title")
plt.title("Top 10 Worst Movies")
plt.show()

# %%
#   viii)longest movies
longest = movies.sort_values("Duration (minutes)",ascending=False)
longest.head()
# Out:
#                             IMDb Rating  Year Certificates      Genre  \
# Title
# Killers of the Flower Moon          7.6  2023            R      Crime
# Animal                              6.2  2023    Not Rated     Action
# The Green Mile                      8.6  1999            R      Crime
# Avengers: Endgame                   8.4  2019        PG-13     Action
# The Wolf of Wall Street             8.2  2013            R  Biography
#
#                                        Director  \
# Title
# Killers of the Flower Moon      Martin Scorsese
# Animal                      Sandeep Reddy Vanga
# The Green Mile                   Frank Darabont
# Avengers: Endgame                 Anthony Russo
# The Wolf of Wall Street         Martin Scorsese
#
#                                                                 Star Cast  \
# Title
# Killers of the Flower Moon  Leonardo DiCaprioRobert De NiroLily Gladstone
# Animal                      Suresh BandaruSaurabh GuptaPranay Reddy Vanga
# The Green Mile                  Tom HanksMichael Clarke DuncanDavid Morse
# Avengers: Endgame               Christopher MarkusStephen McFeelyStan Lee
# The Wolf of Wall Street          Leonardo DiCaprioJonah HillMargot Robbie
#
#                             MetaScore  Duration (minutes)
# Title
# Killers of the Flower Moon       89.0               206.0
# Animal                           33.0               204.0
# The Green Mile                   61.0               189.0
# Avengers: Endgame                78.0               181.0
# The Wolf of Wall Street          75.0               180.0

# %%
# visualizing longest movies 
_10_longest = longest.head(10)
plt.figure(figsize=(10,6))
plt.barh(_10_longest.index, _10_longest["Duration (minutes)"], color="lightcoral")
plt.xlabel("Runtime (minutes)")
plt.ylabel("Movie Title")
plt.title("Top 10 Longest Movies")
plt.gca().invert_yaxis()  
plt.xticks(np.arange(0, _10_longest["Duration (minutes)"].max() + 30, 10)) 
plt.show()

# %%
#   viii)shortest movies
shortest = movies.sort_values("Duration (minutes)")
shortest.head()
# Out:
#                      IMDb Rating  Year Certificates      Genre  \
# Title
# Garfield: The Movie          5.0  2004           PG  Adventure
# Toy Story                    8.3  1995            G  Animation
# Migration                    6.7  2023           PG  Animation
# Migration                    6.7  2023           PG  Animation
# Migration                    6.7  2023           PG  Animation
#
#                             Director  \
# Title
# Garfield: The Movie     Peter Hewitt
# Toy Story              John Lasseter
# Migration            Benjamin Renner
# Migration            Benjamin Renner
# Migration            Benjamin Renner
#
#                                                              Star Cast  \
# Title
# Garfield: The Movie  Breckin MeyerJennifer Love HewittStephen Tobol...
# Toy Story                       John LasseterPete DocterAndrew Stanton
# Migration                          Mike WhiteBenjamin RennerKen Daurio
# Migration                          Mike WhiteBenjamin RennerKen Daurio
# Migration                          Mike WhiteBenjamin RennerKen Daurio
#
#                      MetaScore  Duration (minutes)
# Title
# Garfield: The Movie       27.0                80.0
# Toy Story                 96.0                81.0
# Migration                 56.0                83.0
# Migration                 56.0                83.0
# Migration                 56.0                83.0

# %%
# visualizing shortest movies 
_10_shortest = shortest.head(10)
plt.figure(figsize=(10,6))
plt.barh(_10_shortest.index, _10_shortest["Duration (minutes)"], color="lightcoral")
plt.xlabel("Runtime (minutes)")
plt.ylabel("Movie Title")
plt.title("Top 10 Longest Movies")
plt.gca().invert_yaxis()  
plt.xticks(np.arange(0, _10_shortest["Duration (minutes)"].max() + 30, 5)) 
plt.show()

# %%
#   ix) Enlisting all genres
all_genres = movies.groupby("Genre").size().reset_index(name="Movies")
print(all_genres)
# Out:
#        Genre  Movies
# 0     Action     138
# 1  Adventure      35
# 2  Animation      95
# 3  Biography       4
# 4     Comedy      38
# 5      Crime      31
# 6      Drama      24
# 7    Fantasy       5
# 8     Horror      29
# 9   Thriller       1

# %%
# presenting genres
plt.figure(figsize=(10,6))
plt.bar(all_genres["Genre"], all_genres["Movies"], color="skyblue")
plt.xlabel("Genre")
plt.ylabel("Number of Movies")
plt.title("Number of Movies per Genre")
plt.xticks(rotation=40, ha='right')  # Rotate labels for readability
plt.show()

# %%
#   x)highest rating of each genre
highest_rating = movies.groupby("Genre")["IMDb Rating"].max().reset_index(name="Highest rating")
print(highest_rating)
# Out:
#        Genre  Highest rating
# 0     Action             9.0
# 1  Adventure             8.7
# 2  Animation             8.6
# 3  Biography             8.7
# 4     Comedy             8.5
# 5      Crime             9.2
# 6      Drama             8.0
# 7    Fantasy             7.3
# 8     Horror             8.5
# 9   Thriller             7.4

# %%
#   xi) title of the highest rated movie in each genre
idx_h = movies.groupby("Genre")["IMDb Rating"].idxmax()
highest_rated_per_genre = movies.loc[idx_h, ['Genre', 'IMDb Rating']]
highest_rated_per_genre = highest_rated_per_genre.drop_duplicates(subset="Genre")
print(highest_rated_per_genre)
# Out:
#                      Genre  IMDb Rating
# Title
# The Dark Knight     Action          9.0
# Interstellar     Adventure          8.7
# Spirited Away    Animation          8.6
# Goodfellas       Biography          8.7
# Laapataa Ladies     Comedy          8.5
# The Godfather        Crime          9.2
# The Substance        Drama          8.0
# It                 Fantasy          7.3
# Alien               Horror          8.5
# The Surfer        Thriller          7.4

# %%
# Sort by rating for better visual
highest_rated_sorted = highest_rated_per_genre.sort_values("IMDb Rating", ascending=False)

plt.figure(figsize=(10,6))
bars = plt.barh(highest_rated_sorted["Genre"], highest_rated_sorted["IMDb Rating"], color="green")
plt.xlabel("IMDb Rating")
plt.xticks(np.arange(0,10.5,0.5))
plt.ylabel("Genre")
plt.title("Highest Rated Movie per Genre")
plt.gca().invert_yaxis()

# Add rating + movie name labels
for i, bar in enumerate(bars):
    rating = round(bar.get_width(), 1)
    movie_name = highest_rated_sorted.index[i]  # since title is your index
    plt.text(bar.get_width() - 5,
             bar.get_y() + bar.get_height()/2,
             f"{rating} ({movie_name})",
             va='center',
             color='white')

plt.show()

# %%
#   xii) lowest rating of each genre
lowest_rating = movies.groupby("Genre")["IMDb Rating"].min().reset_index(name="Lowest rating")
print(lowest_rating)
# Out:
#        Genre  Lowest rating
# 0     Action            3.9
# 1  Adventure            5.0
# 2  Animation            5.6
# 3  Biography            5.5
# 4     Comedy            4.8
# 5      Crime            6.0
# 6      Drama            4.4
# 7    Fantasy            5.9
# 8     Horror            4.6
# 9   Thriller            7.4

# %%
#   xiii) title of the lowest rated movie in each genre
idx_l = movies.groupby("Genre")["IMDb Rating"].idxmin()
lowest_rated_per_genre = movies.loc[idx_l, ['Genre', 'IMDb Rating']]
unique_lowest_rated_per_genre = lowest_rated_per_genre.drop_duplicates(subset="Genre")
print(unique_lowest_rated_per_genre)
# Out:
#                            Genre  IMDb Rating
# Title
# Madame Web                Action          3.9
# Garfield: The Movie    Adventure          5.0
# Wish                   Animation          5.6
# Unfrosted              Biography          5.5
# Mother of the Bride       Comedy          4.8
# The Courier                Crime          6.0
# You Can't Run Forever      Drama          4.4
# The Prodigy              Fantasy          5.9
# Monster                   Horror          4.6
# The Surfer              Thriller          7.4

# %%
# Sort by rating for better visual
lowest_rated_sorted = lowest_rated_per_genre.sort_values("IMDb Rating", ascending=False)

plt.figure(figsize=(10,6))
bars = plt.barh(lowest_rated_sorted["Genre"], lowest_rated_sorted["IMDb Rating"], color="green")
plt.xlabel("IMDb Rating")
plt.xticks(np.arange(0,10.5,0.5))
plt.ylabel("Genre")
plt.title("Lowest Rated Movie per Genre")
plt.gca().invert_yaxis()

# Add rating + movie name labels
for i, bar in enumerate(bars):
    rating = round(bar.get_width(), 1)
    movie_name = lowest_rated_sorted.index[i]  # since title is your index
    plt.text(bar.get_width() - 2.5,
             bar.get_y() + bar.get_height()/2,
             f"{rating} ({movie_name})",
             va='center',
             color='white')

plt.show()

# %%
#   xiv) average rating of each genre
average_rating_in_genre = movies.groupby("Genre")["IMDb Rating"].mean().reset_index(name="Average rating")
print(average_rating_in_genre)
# Out:
#        Genre  Average rating
# 0     Action        7.080435
# 1  Adventure        7.368571
# 2  Animation        7.250526
# 3  Biography        7.650000
# 4     Comedy        6.892105
# 5      Crime        7.587097
# 6      Drama        6.954167
# 7    Fantasy        6.900000
# 8     Horror        6.337931
# 9   Thriller        7.400000

# %%
#   xv)Number of movies of each certificate
all_certificates = movies.groupby("Certificates")["IMDb Rating"].size().reset_index(name="Rating")
all_certificates
# Out:
#    Certificates  Rating
# 0           16+       2
# 1      Approved       1
# 2             G      16
# 3         NC-17       1
# 4     Not Rated       4
# 5            PG      93
# 6         PG-13      96
# 7             R     183
# 8          TV-G       2
# 9         TV-MA       1
# 10        TV-PG       1

# %%
#   xvi) best movie of each certificate
idx_h1 = movies.groupby("Certificates")["IMDb Rating"].idxmax()
best_of_certificate = movies.loc[idx_h1,["IMDb Rating","Genre","Certificates"]]
best_of_certificate = best_of_certificate.drop_duplicates(subset="Certificates")
print(best_of_certificate)
# Out:
#                               IMDb Rating      Genre Certificates
# Title
# The Coffee Table                      6.8     Comedy          16+
# 12 Angry Men                          9.0      Crime     Approved
# The Lion King                         6.8  Animation           PG
# The Lion King                         8.5  Animation            G
# A Serbian Film                        5.0     Horror        NC-17
# Mars Express                          7.5  Animation    Not Rated
# The Dark Knight                       9.0     Action        PG-13
# The Godfather                         9.2      Crime            R
# Descendants: The Rise of Red          7.1     Action         TV-G
# Monster                               4.6     Horror        TV-MA
# Mother of the Bride                   4.8     Comedy        TV-PG

# %%
# Normalize ratings for color mapping
norm = plt.Normalize(best_of_certificate["IMDb Rating"].min(), 
                     best_of_certificate["IMDb Rating"].max())
colors = plt.cm.viridis(norm(best_of_certificate["IMDb Rating"]))

plt.figure(figsize=(10, 6))

# Create bars with colormap
bars = plt.bar(
    best_of_certificate["Certificates"],
    best_of_certificate["IMDb Rating"],
    color=colors
)

# Add labels above bars
for i, v in enumerate(best_of_certificate["IMDb Rating"]):
    plt.text(i, v + 0.05, f"{v:.1f}", ha='center', fontsize=9)

# Labels & title
plt.xlabel("Certificate")
plt.ylabel("IMDb Rating")
plt.title("Highest Rated Movie for Each Certificate")

plt.show()

# %%
#   xvi) best movie of each certificate
idx_l1 = movies.groupby("Certificates")["IMDb Rating"].idxmin()
worst_of_certificate = movies.loc[idx_l1,["IMDb Rating","Genre","Certificates"]]
unique_W_O_C = worst_of_certificate.drop_duplicates(subset="Certificates")
print(unique_W_O_C)
# Out:
#                               IMDb Rating      Genre Certificates
# Title
# The Coffee Table                      6.8     Comedy          16+
# 12 Angry Men                          9.0      Crime     Approved
# Cars                                  7.2  Animation            G
# A Serbian Film                        5.0     Horror        NC-17
# Animal                                6.2     Action    Not Rated
# Garfield: The Movie                   5.0  Adventure           PG
# Madame Web                            3.9     Action        PG-13
# You Can't Run Forever                 4.4      Drama            R
# Descendants: The Rise of Red          7.1     Action         TV-G
# Monster                               4.6     Horror        TV-MA
# Mother of the Bride                   4.8     Comedy        TV-PG

# %%
#   xvii) year wise distribution of movies
year_wise = movies.groupby("Year").size().reset_index(name="Movies Realeased")
year_wise
# Out:
#     Year  Movies Realeased
# 0   1939                 1
# 1   1957                 1
# 2   1968                 2
# 3   1971                 1
# 4   1972                 1
# 5   1976                 1
# 6   1979                 5
# 7   1981                 3
# 8   1983                 1
# 9   1984                 5
# 10  1985                 3
# 11  1986                 1
# 12  1987                 1
# 13  1988                 1
# 14  1990                 1
# 15  1991                 1
# 16  1993                 3
# 17  1994                 6
# 18  1995                 4
# 19  1996                 2
# 20  1997                 3
# 21  1999                 5
# 22  2000                 1
# 23  2001                11
# 24  2002                 3
# 25  2003                 3
# 26  2004                 7
# 27  2005                 3
# 28  2006                 3
# 29  2007                 6
# 30  2008                 5
# 31  2009                 2
# 32  2010                 4
# 33  2011                 3
# 34  2012                 2
# 35  2013                 6
# 36  2014                 8
# 37  2015                 9
# 38  2016                 8
# 39  2017                 8
# 40  2018                12
# 41  2019                10
# 42  2021                 9
# 43  2022                18
# 44  2023                63
# 45  2024               143
# 46  2025                 1

# %%
plt.figure(figsize=(12, 6))
plt.plot(year_wise["Year"], year_wise["Movies Realeased"], marker='*', color="blue", linewidth=1)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Number of Movies Released")
plt.title("Movies Released per Year")
plt.grid(True, linestyle="--", alpha=0.6)

plt.show()

# %%
#   xviii) best movie years
high_movie_years = year_wise.sort_values("Movies Realeased",ascending=False,ignore_index=True)
high_movie_years.head(10)
# Out:
#    Year  Movies Realeased
# 0  2024               143
# 1  2023                63
# 2  2022                18
# 3  2018                12
# 4  2001                11
# 5  2019                10
# 6  2015                 9
# 7  2021                 9
# 8  2016                 8
# 9  2017                 8

# %%
#   xix) highest rated film in each year
idx_h2 = movies.groupby("Year")["IMDb Rating"].idxmax()
highest_rated_per_year = movies.loc[idx_h2,["Year","IMDb Rating","Genre","Certificates"]]
highest_rated_per_year = highest_rated_per_year.drop_duplicates(subset="Year")
highest_rated_per_year
# Out:
#                                               Year  IMDb Rating      Genre  \
# Title
# The Wizard of Oz                              1939          8.1  Adventure
# 12 Angry Men                                  1957          9.0      Crime
# Planet of the Apes                            1968          8.0  Adventure
# Planet of the Apes                            2001          5.7     Action
# Willy Wonka & the Chocolate Factory           1971          7.8  Adventure
# The Godfather                                 1972          9.2      Crime
# Taxi Driver                                   1976          8.2      Crime
# Alien                                         1979          8.5     Horror
# Mad Max 2: The Road Warrior                   1981          7.6     Action
# The Outsiders                                 1983          7.0      Crime
# Ghostbusters                                  1984          7.8     Action
# The Goonies                                   1985          7.7  Adventure
# Castle in the Sky                             1986          8.0  Animation
# The Princess Bride                            1987          8.0  Adventure
# Beetlejuice                                   1988          7.5     Comedy
# Goodfellas                                    1990          8.7  Biography
# The Silence of the Lambs                      1991          8.6      Crime
# Jurassic Park                                 1993          8.2     Action
# Pulp Fiction                                  1994          8.9      Crime
# Se7en                                         1995          8.6      Crime
# Twister                                       1996          6.5     Action
# The Fifth Element                             1997          7.6     Action
# The Matrix                                    1999          8.7     Action
# Gladiator                                     2000          8.5     Action
# 28 Days Later                                 2002          7.5      Drama
# Finding Nemo                                  2003          8.2  Animation
# Howl's Moving Castle                          2004          8.2  Animation
# Harry Potter and the Goblet of Fire           2005          7.7  Adventure
# The Departed                                  2006          8.5      Crime
# No Country for Old Men                        2007          8.2      Crime
# The Dark Knight                               2008          9.0     Action
# Inglourious Basterds                          2009          8.4  Adventure
# Inception                                     2010          8.8     Action
# Harry Potter and the Deathly Hallows: Part 2  2011          8.1  Adventure
# The Hunger Games                              2012          7.2     Action
# Prisoners                                     2013          8.2      Crime
# Interstellar                                  2014          8.7  Adventure
# Inside Out                                    2015          8.1  Animation
# Your Name.                                    2016          8.4  Animation
# Coco                                          2017          8.4  Animation
# Spider-Man: Into the Spider-Verse             2018          8.4  Animation
# Joker                                         2019          8.4      Crime
# Spider-Man: No Way Home                       2021          8.2     Action
# Puss in Boots: The Last Wish                  2022          7.8  Animation
# Spider-Man: Across the Spider-Verse           2023          8.6  Animation
# Dune: Part Two                                2024          8.6     Action
# Minecraft                                     2025          7.1     Action
#
#                                              Certificates
# Title
# The Wizard of Oz                                        G
# 12 Angry Men                                     Approved
# Planet of the Apes                                      G
# Planet of the Apes                                  PG-13
# Willy Wonka & the Chocolate Factory                     G
# The Godfather                                           R
# Taxi Driver                                             R
# Alien                                                   R
# Mad Max 2: The Road Warrior                             R
# The Outsiders                                          PG
# Ghostbusters                                           PG
# The Goonies                                            PG
# Castle in the Sky                                      PG
# The Princess Bride                                     PG
# Beetlejuice                                            PG
# Goodfellas                                              R
# The Silence of the Lambs                                R
# Jurassic Park                                       PG-13
# Pulp Fiction                                            R
# Se7en                                                   R
# Twister                                             PG-13
# The Fifth Element                                   PG-13
# The Matrix                                              R
# Gladiator                                               R
# 28 Days Later                                           R
# Finding Nemo                                            G
# Howl's Moving Castle                                   PG
# Harry Potter and the Goblet of Fire                 PG-13
# The Departed                                            R
# No Country for Old Men                                  R
# The Dark Knight                                     PG-13
# Inglourious Basterds                                    R
# Inception                                           PG-13
# Harry Potter and the Deathly Hallows: Part 2        PG-13
# The Hunger Games                                    PG-13
# Prisoners                                               R
# Interstellar                                        PG-13
# Inside Out                                             PG
# Your Name.                                              R
# Coco                                                   PG
# Spider-Man: Into the Spider-Verse                      PG
# Joker                                                   R
# Spider-Man: No Way Home                             PG-13
# Puss in Boots: The Last Wish                           PG
# Spider-Man: Across the Spider-Verse                    PG
# Dune: Part Two                                      PG-13
# Minecraft                                               R
